# %%
import pandas as pd
import numpy as np

# %%
# Study data files
countryhappiness_path = "country_trial.csv"

# Read the mouse data and the study results
country_happiness = pd.read_csv(countryhappiness_path)

country_happiness
# Out:
#      Overall rank Country Code               Country  \
# 0           153.0          AFG           Afghanistan
# 1           137.0          AGO                Angola
# 2            95.0          ALB               Albania
# 3            20.0          ARE  United Arab Emirates
# 4            30.0          ARG             Argentina
# ..            ...          ...                   ...
# 155          69.0          XKX                Kosovo
# 156         136.0          YEM                 Yemen
# 157         113.0          ZAF          South Africa
# 158          85.0          ZMB                Zambia
# 159         115.0          ZWE              Zimbabwe
#
#                               Region       Languages   Religion  Population  \
# 0                      Southern Asia    Asia (other)     Muslim  34414000.0
# 1                 Sub-Saharan Africa      Portuguese  Christian  27884000.0
# 2                     Eastern Europe  Europe (other)     Muslim   2891000.0
# ...

# %%
#Creating data frame with happiness scores
Happiness_fouryears = country_happiness.loc[:,['Country', '2015 Happiness Score','2016 Happiness Score',
                                               '2017 Happiness Score','2018 Happiness Score','2019 Happiness Score']]

# %%
Happiness_fouryears
# Out:
#                   Country  2015 Happiness Score  2016 Happiness Score  \
# 0             Afghanistan                  3.58                  3.36
# 1                  Angola                  4.03                  3.87
# 2                 Albania                  4.96                  4.66
# 3    United Arab Emirates                  6.90                  6.57
# 4               Argentina                  6.57                  6.65
# ..                    ...                   ...                   ...
# 155                Kosovo                  5.59                  5.40
# 156                 Yemen                  4.08                  3.72
# 157          South Africa                  4.64                  4.46
# 158                Zambia                  5.13                  4.80
# 159              Zimbabwe                  4.61                  4.19
#
#      2017 Happiness Score  2018 Happiness Score  2019 Happiness Score
# ...

# %%
#check and count null values
Happiness_fouryears['2015 Happiness Score'].isnull().sum()
Happiness_fouryears['2017 Happiness Score'].isnull().sum()
Happiness_fouryears['2018 Happiness Score'].isnull().sum()
Happiness_fouryears['2019 Happiness Score'].isnull().sum()

# We could drop these countries without happiness scores in certain years but there's not many empty values, 
#let's fill the data instead through a logical way

Incomplete_Countries = Happiness_fouryears[Happiness_fouryears.isna().any(axis=1)]
Incomplete_Countries
# Out:
#                       Country  2015 Happiness Score  2016 Happiness Score  \
# 1                      Angola                  4.03                  3.87
# 18                     Belize                   NaN                  5.96
# 23   Central African Republic                  3.68                   NaN
# 33                    Comoros                  3.96                  3.96
# 38                   Djibouti                  4.37                   NaN
# 54                     Gambia                   NaN                   NaN
# 79                       Laos                  4.88                  4.88
# 84                    Lesotho                  4.90                   NaN
# 98                 Mozambique                  4.97                   NaN
# 103                   Namibia                   NaN                  4.57
# 111                      Oman                  6.85                   NaN
# 117               Puerto Rico                   NaN                  7.04
# ...

# %%
# To decide the most logical value we'll run thrugh each country

#Countries with no value changes
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Angola",'2019 Happiness Score']=3.8
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Belize",{'2015 Happiness Score','2019 Happiness Score'}]=5.96
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Comoros",{'2017 Happiness Score','2018 Happiness Score'}]=3.96
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Djibouti",{'2016 Happiness Score','2017 Happiness Score'}]=4.37
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Djibouti",{'2018 Happiness Score','2019 Happiness Score'}]=4.37
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Gambia",{'2015 Happiness Score','2016 Happiness Score'}]=4.52
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Gambia",{'2017 Happiness Score','2018 Happiness Score'}]=4.52
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Oman",{'2016 Happiness Score','2017 Happiness Score'}]=6.85
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Oman",{'2018 Happiness Score','2019 Happiness Score'}]=6.85
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Puerto Rico",{'2015 Happiness Score','2017 Happiness Score'}]=7.04
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Puerto Rico",{'2018 Happiness Score','2019 Happiness Score'}]=7.04
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Suriname",{'2017 Happiness Score','2018 Happiness Score'}]=6.27
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Suriname",'2019 Happiness Score']=6.27
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Namibia",'2015 Happiness Score']=4.57
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Sudan",'2019 Happiness Score']=4.14

# Countries with value changes, do a linear transition
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Central African Republic",'2016 Happiness Score']=(3.86+2.69)/2
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Laos",'2017 Happiness Score']=(4.88+4.62)/2
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Lesotho",'2016 Happiness Score']=(4.90+3.81)/2
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Mozambique",'2016 Happiness Score']=(4.97+4.55)/2
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Somalia",'2015 Happiness Score']=(5.44+(5.44-5.15))
Happiness_fouryears.at[Happiness_fouryears["Country"]=="South Sudan",'2015 Happiness Score']=(3.83+(3.88-3.59))
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Swaziland",'2016 Happiness Score']=4.87-(4.87-4.21)/3
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Swaziland",'2017 Happiness Score']=4.65-(4.87-4.21)/3
Happiness_fouryears.at[Happiness_fouryears["Country"]=="Swaziland",'2018 Happiness Score']=4.43-(4.87-4.21)/3


#checker
Incomplete_Countries = Happiness_fouryears[Happiness_fouryears.isna().any(axis=1)]
Incomplete_Countries
# Out:
# Empty DataFrame
# Columns: [Country, 2015 Happiness Score, 2016 Happiness Score, 2017 Happiness Score, 2018 Happiness Score, 2019 Happiness Score]
# Index: []

# %%
Happiness_fouryears
# Out:
#                   Country  2015 Happiness Score  2016 Happiness Score  \
# 0             Afghanistan                  3.58                  3.36
# 1                  Angola                  4.03                  3.87
# 2                 Albania                  4.96                  4.66
# 3    United Arab Emirates                  6.90                  6.57
# 4               Argentina                  6.57                  6.65
# ..                    ...                   ...                   ...
# 155                Kosovo                  5.59                  5.40
# 156                 Yemen                  4.08                  3.72
# 157          South Africa                  4.64                  4.46
# 158                Zambia                  5.13                  4.80
# 159              Zimbabwe                  4.61                  4.19
#
#      2017 Happiness Score  2018 Happiness Score  2019 Happiness Score
# ...

# %%
#creating dataframes to each year
Hapiness_2015=pd.DataFrame(Happiness_fouryears[{"Country","2015 Happiness Score"}])
Hapiness_2016=pd.DataFrame(Happiness_fouryears[{"Country","2016 Happiness Score"}])
Hapiness_2017=pd.DataFrame(Happiness_fouryears[{"Country","2017 Happiness Score"}])
Hapiness_2018=pd.DataFrame(Happiness_fouryears[{"Country","2018 Happiness Score"}])
Hapiness_2019=pd.DataFrame(Happiness_fouryears[{"Country","2019 Happiness Score"}])

# %%
#add a column with the mean
Happiness_fouryears['Hapiness_Mean'] = Happiness_fouryears.mean(axis=1)

# %%
#creating a df with country and mean
Happiness_mean = pd.DataFrame(Happiness_fouryears[{"Country","Hapiness_Mean"}])

Happiness_mean
# Out:
#      Hapiness_Mean               Country
# 0            3.512           Afghanistan
# 1            3.860                Angola
# 2            4.714               Albania
# 3            6.744  United Arab Emirates
# 4            6.460             Argentina
# ..             ...                   ...
# 155          5.606                Kosovo
# 156          3.626                 Yemen
# 157          4.674          South Africa
# 158          4.586                Zambia
# 159          4.006              Zimbabwe
#
# [160 rows x 2 columns]

# %%
Culture_df = pd.DataFrame(country_happiness[{"Country","Region","Religion","Languages","Christian","Muslim","Irreligion","Hindu","Buddhist",
                                             "Folk religion","Other religion","Jewish"}])

# %%
#Dataframe with cultural traits
Culture_df
# Out:
#           Languages  Christian  Folk religion               Country  \
# 0      Asia (other)        0.1            0.0           Afghanistan
# 1        Portuguese       90.5            4.2                Angola
# 2    Europe (other)       18.0            0.0               Albania
# 3            Arabic       12.6            0.0  United Arab Emirates
# 4           Spanish       85.2            0.8             Argentina
# ..              ...        ...            ...                   ...
# 155  Europe (other)       11.4            0.0                Kosovo
# 156          Arabic        0.2            0.0                 Yemen
# 157         English       81.2            0.4          South Africa
# 158         English       97.6            0.3                Zambia
# 159         English       87.0            3.8              Zimbabwe
#
#                               Region  Buddhist  Hindu  Jewish   Religion  \
# 0                      Southern Asia      0.00   0.03    0.00     Muslim
# ...

# %%
#standardise predominant religion

Culture_df["Religion_Muslim"] = 0
Culture_df.loc[Culture_df.Religion == "Muslim", 'Religion_Muslim'] = 1
Culture_df["Religion_Christian"] = 0
Culture_df.loc[Culture_df.Religion == "Christian", 'Religion_Christian'] = 1
Culture_df["Religion_Buddhist"] = 0
Culture_df.loc[Culture_df.Religion == "Buddhist", 'Religion_Buddhist'] = 1
Culture_df["Religion_Atheist"] = 0
Culture_df.loc[Culture_df.Religion == "Atheist", 'Religion_Atheist'] = 1
Culture_df["Religion_Mixed"] = 0
Culture_df.loc[Culture_df.Religion == "Religion_Mixed", 'Religion_Mixed'] = 1
Culture_df["Religion_Jewish"] = 0
Culture_df.loc[Culture_df.Religion == "Religion_Jewish", 'Religion_Jewish'] = 1
Culture_df["Religion_Folk Religion"] = 0
Culture_df.loc[Culture_df.Religion == "Religion_Folk Religion", "Religion_Folk Religion"] = 1
Culture_df["Religion_Hindu"] = 0
Culture_df.loc[Culture_df.Religion == "Religion_Hindu", 'Religion_Hindu'] = 1

#Standardize Languages
Culture_df["Language_Asia (other)"] = 0
Culture_df.loc[Culture_df.Languages == "Asia (other)", 'Language_Asia (other)'] = 1
Culture_df["Language_Portuguese"] = 0
Culture_df.loc[Culture_df.Languages  == "Portuguese", 'Language_Portuguese'] = 1
Culture_df["Language_Europe (other)"] = 0
Culture_df.loc[Culture_df.Languages  == "Europe (other)", 'Language_Europe (other)'] = 1
Culture_df["Language_Arabic"] = 0
Culture_df.loc[Culture_df.Languages  == "Arabic", 'Language_Arabic'] = 1
Culture_df["Language_Spanish"] = 0
Culture_df.loc[Culture_df.Languages  == "Spanish", 'Language_Spanish'] = 1
Culture_df["Language_English"] = 0
Culture_df.loc[Culture_df.Languages  == "English", 'Language_English'] = 1
Culture_df["Language_German"] = 0
Culture_df.loc[Culture_df.Languages  == "German", 'Language_German'] = 1
Culture_df["Language_French"] = 0
Culture_df.loc[Culture_df.Languages == "French", 'Language_French'] = 1
Culture_df["Language_Chinese"] = 0
Culture_df.loc[Culture_df.Languages == "Chinese", 'Language_Chinese'] = 1
Culture_df["Language_African (other)"] = 0
Culture_df.loc[Culture_df.Languages == "African (other)", 'Language_African (other)'] = 1
Culture_df["Language_Hindi"] = 0
Culture_df.loc[Culture_df.Languages == "Hindi", 'Language_Hindi'] = 1
Culture_df["Language_Persian"] = 0
Culture_df.loc[Culture_df.Languages == "Persian", 'Language_Persian'] = 1
Culture_df["Language_Japanese"] = 0
Culture_df.loc[Culture_df.Languages == "Japanese", 'Language_Japanese'] = 1
Culture_df["Language_Russian"] = 0
Culture_df.loc[Culture_df.Languages == "Russian", 'Language_Russian'] = 1


#Standardise regions
Culture_df["Region_Southern Asia"] = 0
Culture_df.loc[Culture_df.Region == "Southern Asia", 'Region_Southern Asia'] = 1
Culture_df["Region_Sub-Saharan Africa"] = 0
Culture_df.loc[Culture_df.Region == "Sub-Saharan Africa", 'Region_Sub-Saharan Africa'] = 1
Culture_df["Region_Eastern Europe"] = 0
Culture_df.loc[Culture_df.Region == "Eastern Europe", 'Region_Eastern Europe'] = 1
Culture_df["Region_Middle East and Northern Africa"] = 0
Culture_df.loc[Culture_df.Region == "Middle East and Northern Africa", 'Region_Middle East and Northern Africa'] = 1
Culture_df["Region_Latin America and Caribbean"] = 0
Culture_df.loc[Culture_df.Region == "Latin America and Caribbean", 'Region_Latin America and Caribbean'] = 1
Culture_df["Region_Australia and New Zealand"] = 0
Culture_df.loc[Culture_df.Region == "Australia and New Zealand", 'Region_Australia and New Zealand'] = 1
Culture_df["Region_Northern Europe"] = 0
Culture_df.loc[Culture_df.Region == "Northern Europe", 'Region_Northern Europe'] = 1
Culture_df["Region_Southeastern Asia"] = 0
Culture_df.loc[Culture_df.Region == "Southeastern Asia", 'Region_Southeastern Asia'] = 1               
Culture_df["Region_Eastern Asia"] = 0
Culture_df.loc[Culture_df.Region == "Eastern Asia", 'Region_Eastern Asia'] = 1
Culture_df["Region_Southern Europe"] = 0
Culture_df.loc[Culture_df.Region == "Southern Europe", 'Region_Southern Europe'] = 1
Culture_df["Region_Central Asia"] = 0
Culture_df.loc[Culture_df.Region == "Central Asia", 'Region_Central Asia'] = 1



# Southern Asia
# Sub-Saharan Africa
# Eastern Europe
# Middle East and Northern Africa
# Latin America and Caribbean
# Central Asia
# Australia and New Zealand
# Northern Europe
# Southeastern Asia
# Eastern Asia
#Southern Europe




Culture_df
# Out:
#           Languages  Christian  Folk religion               Country  \
# 0      Asia (other)        0.1            0.0           Afghanistan
# 1        Portuguese       90.5            4.2                Angola
# 2    Europe (other)       18.0            0.0               Albania
# 3            Arabic       12.6            0.0  United Arab Emirates
# 4           Spanish       85.2            0.8             Argentina
# ..              ...        ...            ...                   ...
# 155  Europe (other)       11.4            0.0                Kosovo
# 156          Arabic        0.2            0.0                 Yemen
# 157         English       81.2            0.4          South Africa
# 158         English       97.6            0.3                Zambia
# 159         English       87.0            3.8              Zimbabwe
#
#                               Region  Buddhist  Hindu  Jewish   Religion  \
# 0                      Southern Asia      0.00   0.03    0.00     Muslim
# ...

# %%
Cultureadd_df = pd.DataFrame(country_happiness[{"Country","Individualism","Masculinity","Uncertainity Avoidance","Long Term Orientation","Power Distance"}])

#drop countries with null values, only 65 countries to be analysed
Cultureadd_df = Cultureadd_df.dropna()

# %%
#check and select columns for economic factors
country_happiness

# iterating the columns 
for col in country_happiness.columns: 
    print(col) # iterating the columns
# Out:
# Overall rank
# Country Code
# Country
# Region
# Languages
# Religion
# Population
# Area (km2)
# 2015 Happiness Score
# 2016 Happiness Score
# 2017 Happiness Score
# 2018 Happiness Score
# 2019 Happiness Score
# 2015 GDP
# 2016 GDP
# 2017 GDP
# 2018 GDP
# 2019 GDP
# 2015 Family
# 2016 Family
# 2017 Family
# 2018 Family
# 2019 Family
# 2015 Health
# 2016 Health
# 2017 Health
# 2018 Health
# 2019 Health
# 2015 Freedom
# 2016 Freedom
# 2017 Freedom
# 2018 Freedom
# 2019 Freedom
# 2015 Corruption
# 2016 Corruption
# 2017 Corruption
# 2018 Corruption
# 2019 Corruption
# 2015 Generosity
# 2016 Generosity
# 2017 Generosity
# 2018 Generosity
# 2019 Generosity
# 2015 GDP per Cap
# 2016 GDP per Cap
# 2017 GDP per Cap
# 2018 GDP per Cap
# 2019 GDP per Cap
# Gender Ratio %
# Gender Gap
# 2015 Suicide per 100k
# 2016 Suicide per 100k
# 2015 Suicide 5-14 years
# 2016 Suicide 5-14 years
# 2015Suicide 15-49 years
# 2016 Suicide 15-49 years
# 2015 Suicide  50-69 years
# 2016 Suicide  50-69 years
# ...

# %%
Economic_df = pd.DataFrame(country_happiness[{"Country","2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap",
                                              "2019 GDP per Cap","GINI","Hunger (rate)",
                                              "Urbanization (rate)","Air Quality (Value)","Congestion (Per capita)",
                                              "Net Migration","Unemployment (%)"}])

Economic_df

#alternative for developed countries only
Economicdev_df = pd.DataFrame(country_happiness[{"Country","2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap",
                                              "2019 GDP per Cap","GINI",
                                              "Urbanization (rate)",
                                              "Net Migration","Unemployment (%)"}])

# %%
Economic_df['GDP_Mean'] = Economic_df[{"2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap",
                                              "2019 GDP per Cap"}].mean(axis=1)

Economicdev_df['GDP_Mean'] = Economicdev_df[{"2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap",
                                              "2019 GDP per Cap"}].mean(axis=1)

Economic_df
# Out:
#      2019 GDP per Cap  2018 GDP per Cap  Congestion (Per capita)  \
# 0              502.12            524.16                      NaN
# 1             2973.59           3289.65                      NaN
# 2             5352.86           5284.38                      NaN
# 3            43103.32          43839.36                   170.89
# 4            10006.15          11683.95                   172.79
# ..                ...               ...                      ...
# 155           4417.51           4419.91                      NaN
# 156              0.00            968.16                      NaN
# 157           6001.40           6374.03                   191.72
# 158           1291.34           1556.33                      NaN
# 159           1463.99           1683.74                      NaN
#
#      Net Migration  2016 GDP per Cap               Country  Unemployment (%)  \
# 0              3.3            547.23           Afghanistan              8.86
# ...

# %%
Incomplete_Countries = Economic_df[Economic_df.isna().any(axis=1)]


Incomplete_Countries
# Out:
#      2019 GDP per Cap  2018 GDP per Cap  Congestion (Per capita)  \
# 0              502.12            524.16                      NaN
# 1             2973.59           3289.65                      NaN
# 2             5352.86           5284.38                      NaN
# 3            43103.32          43839.36                   170.89
# 5             4622.73           4220.49                      NaN
# ..                ...               ...                      ...
# 153              0.00              0.00                   155.42
# 155           4417.51           4419.91                      NaN
# 156              0.00            968.16                      NaN
# 158           1291.34           1556.33                      NaN
# 159           1463.99           1683.74                      NaN
#
#      Net Migration  2016 GDP per Cap               Country  Unemployment (%)  \
# 0              3.3            547.23           Afghanistan              8.86
# ...

# %%
#should we drop some columns and get more data?
Incomplete_Countries.isnull().sum(axis = 0)
# Out:
# 2019 GDP per Cap            0
# 2018 GDP per Cap            0
# Congestion (Per capita)    77
# Net Migration               5
# 2016 GDP per Cap            0
# Country                     0
# Unemployment (%)            2
# 2015 GDP per Cap            0
# 2017 GDP per Cap            0
# Hunger (rate)              51
# GINI                       12
# Air Quality (Value)        66
# Urbanization (rate)         4
# GDP_Mean                    0
# dtype: int64

# %%
#Not bad to drop all columns because we will be comparing the worst economically, exactly what we think it's a differentiator
Economic_df = Economic_df.dropna()

Economicdev_df = Economicdev_df.dropna()

# %%
Social_df = pd.DataFrame(country_happiness[{"Country","Gender Ratio %","Democracy (value)",
                                              "Holiday (Paid Days)","Prison (per 100k)","Alchool (per cap)",
                                              "Alchool (per cap)","Homicide per 100k","Fertility (per woman)","2016 Suicide per 100k",
                                           "2016 Suicide 5-14 years","2016 Suicide 15-49 years","2016 Suicide  50-69 years","2016 Suicide 70+ years",
                                           "2015 Suicide per 100k", "2015 Suicide 5-14 years","2015Suicide 15-49 years","2015 Suicide  50-69 years",
                                            "2015 Suicide 70+ years"}])

# %%
Incomplete_Social = Social_df[Social_df.isna().any(axis=1)]
Incomplete_Social.isnull().sum(axis = 0)

Social_df['Suicide 5-14 years'] = Social_df[{"2016 Suicide 5-14 years","2015 Suicide 5-14 years"}].mean(axis=1)
Social_df['Suicide 15-49 years'] = Social_df[{"2016 Suicide 15-49 years","2015Suicide 15-49 years"}].mean(axis=1)
Social_df['Suicide 50-69 years'] = Social_df[{"2016 Suicide  50-69 years","2015 Suicide  50-69 years"}].mean(axis=1)
Social_df['Suicide 70+ years'] = Social_df[{"2016 Suicide 70+ years","2015 Suicide 70+ years"}].mean(axis=1)

# %%
# Decided to drop gender gap and divorce as they lack substantial data
Social_df = Social_df.dropna()
Social_df
# Out:
#      2016 Suicide 70+ years  Prison (per 100k)  Fertility (per woman)  \
# 0                     22.28               87.0                   4.98
# 1                     54.89               93.0                   5.77
# 2                     10.01              177.0                   1.68
# 3                      8.89              104.0                   1.54
# 4                     20.30              230.0                   2.30
# ..                      ...                ...                    ...
# 154                   21.50              128.0                   2.01
# 156                    8.78               53.0                   4.10
# 157                   20.28              275.0                   2.48
# 158                   66.59              123.0                   4.92
# 159                   86.14              114.0                   3.90
#
#      Homicide per 100k               Country  2016 Suicide per 100k  \
# ...

# %%
# Country breakdown (developed is to distinguish the very wealthy)

Developed_countries = ["Luxembourg","Switzerland","Ireland","Norway","Iceland","Singapore","United States","Qatar","Denmark",
                       "Australia","Netherlands","Sweden","Austria","Hong Kong","Finland","Germany","Canada","Belgium","Israel",
                       "United Arab Emirates","United Kingdom","New Zealand","France","Japan","Italy","Kuwait","South Korea","Spain"] 

Developing_countries = ["Iran","Kosovo","Slovenia","Cyprus","Estonia","Montenegro","Belarus","Czech Republic","Lithuania","Hungary",
                        "Portugal","Latvia","Greece","Poland","Croatia","Serbia","Slovakia","Russia","Bosnia and Herzegovina",
                        "North Macedonia","Bulgaria","Saudi Arabia","Romania","Bahrain","Chile","Malta","Uruguay","Sri Lanka",
                        "Lebanon","China","Ukraine","Malaysia","Costa Rica","Thailand","Argentina","Georgia","Turkey","Albania",
                        "Kazakhstan","Libya","Peru","Armenia","El Salvador","Colombia","Jamaica","Ecuador","Mexico","Brazil","Moldova",
                        "Panama","Jordan","Mongolia","Mauritius","Nicaragua","Tunisia","Honduras","Uzbekistan","Trinidad and Tobago",
                        "Vietnam","Kyrgyzstan","Paraguay","Egypt","Azerbaijan","Morocco","Algeria","Indonesia","Guatemala","Venezuela",
                        "Bolivia","Philippines","Iraq","Cambodia","Dominican Republic","Bhutan","Bangladesh","South Africa","India"]


Underdeveloped_countries = ["Botswana","Gabon","Turkmenistan","Namibia","Swaziland","Laos","Ivory Coast","Nigeria","Ghana",
                            "Congo (Brazzaville)","Kenya","Mauritania","Cameroon","Zimbabwe","Senegal","Myanmar","Comoros",
                            "Zambia","Pakistan","Benin","Lesotho","Tanzania","South Sudan","Nepal","Yemen","Guinea","Mali",
                            "Tajikistan","Ethiopia","Rwanda","Uganda","Burkina Faso","Haiti","Gambia","Chad","Togo","Liberia",
                            "Niger","Congo (Kinshasa)","Madagascar","Sierra Leone","Afghanistan","Mozambique",
                            "Central African Republic","Malawi","Somalia","Burundi","Syria"]

# %%
#breakdown for happiness
Happiness_developed = Happiness_fouryears[Happiness_fouryears['Country'].isin(Developed_countries)]
Happiness_developing = Happiness_fouryears[Happiness_fouryears['Country'].isin(Developing_countries)]
Happiness_underdeveloped = Happiness_fouryears[Happiness_fouryears['Country'].isin(Underdeveloped_countries)]

#breakdown for happiness means
Happiness_mean_developed = Happiness_mean[Happiness_mean['Country'].isin(Developed_countries)]
Happiness_mean_developing = Happiness_mean[Happiness_mean['Country'].isin(Developing_countries)]
Happiness_mean_underdeveloped = Happiness_mean[Happiness_mean['Country'].isin(Underdeveloped_countries)]


#breakdown for culture
Culture_developed = Culture_df[Culture_df['Country'].isin(Developed_countries)]
Culture_developing = Culture_df[Culture_df['Country'].isin(Developing_countries)]
Culture_underdeveloped = Culture_df[Culture_df['Country'].isin(Underdeveloped_countries)]


#breakdown for aditional culture
Behaviour_developed = Cultureadd_df[Cultureadd_df['Country'].isin(Developed_countries)]
Behaviour_developing = Cultureadd_df[Cultureadd_df['Country'].isin(Developing_countries)]
Behaviour_underdeveloped = Cultureadd_df[Cultureadd_df['Country'].isin(Underdeveloped_countries)]

#breakdown for economic
Economic_developed = Economicdev_df[Economicdev_df['Country'].isin(Developed_countries)] #should not have data for wealthy countries! But now has bc it is a special dataframe
Economic_developing = Economic_df[Economic_df['Country'].isin(Developing_countries)]
Economic_underdeveloped = Economic_df[Economic_df['Country'].isin(Underdeveloped_countries)]

#breakdown for social
Social_developed = Social_df[Social_df['Country'].isin(Developed_countries)]
Social_developing = Social_df[Social_df['Country'].isin(Developing_countries)]
Social_underdeveloped = Social_df[Social_df['Country'].isin(Underdeveloped_countries)]

# %%
#Developing happiness frames for each section
Happiness_mean_Culture_developed = Happiness_mean_developed[Happiness_developed["Country"].isin(Culture_developed["Country"])]
Happiness_mean_Culture_developing = Happiness_mean_developing[Happiness_mean_developing["Country"].isin(Culture_developing["Country"])]
Happiness_mean_Culture_underdeveloped = Happiness_mean_underdeveloped[Happiness_mean_underdeveloped["Country"].isin(Culture_underdeveloped["Country"])]

Happiness_mean_Behaviour_developed = Happiness_mean_developed[Happiness_developed["Country"].isin(Behaviour_developed["Country"])]
Happiness_mean_Behaviour_developing = Happiness_mean_developing[Happiness_mean_developing["Country"].isin(Behaviour_developing["Country"])]
Happiness_mean_Behaviour_underdeveloped = Happiness_mean_underdeveloped[Happiness_mean_underdeveloped["Country"].isin(Behaviour_underdeveloped["Country"])]

Happiness_mean_Economic_developed = Happiness_mean_developed[Happiness_developed["Country"].isin(Economic_developed["Country"])]
Happiness_mean_Economic_developing = Happiness_mean_developing[Happiness_mean_developing["Country"].isin(Economic_developing["Country"])]
Happiness_mean_Economic_underdeveloped = Happiness_mean_underdeveloped[Happiness_mean_underdeveloped["Country"].isin(Economic_underdeveloped["Country"])]

Happiness_mean_Social_developed = Happiness_mean_developed[Happiness_developed["Country"].isin(Social_developed["Country"])]
Happiness_mean_Social_developing = Happiness_mean_developing[Happiness_mean_developing["Country"].isin(Social_developing["Country"])]
Happiness_mean_Social_underdeveloped = Happiness_mean_underdeveloped[Happiness_mean_underdeveloped["Country"].isin(Social_underdeveloped["Country"])]

# %%
#time to drop columns this is fun!

#trim culture
Happiness_Culture_developed_trim = Happiness_mean_Culture_developed.drop("Country", 1)
Happiness_Culture_developing_trim = Happiness_mean_Culture_developing.drop("Country", 1)
Happiness_Culture_underdeveloped_trim = Happiness_mean_Culture_underdeveloped.drop("Country", 1)


Happiness_Behaviour_developed_trim = Happiness_mean_Behaviour_developed.drop("Country", 1)
Happiness_Behaviour_developing_trim = Happiness_mean_Behaviour_developing.drop("Country", 1)
Happiness_Behaviour_underdeveloped_trim = Happiness_mean_Behaviour_underdeveloped.drop("Country", 1)


Happiness_Economic_developed_trim = Happiness_mean_Economic_developed.drop("Country", 1)
Happiness_Economic_developing_trim = Happiness_mean_Economic_developing.drop("Country", 1)
Happiness_Economic_underdeveloped_trim = Happiness_mean_Economic_underdeveloped.drop("Country", 1)



Happiness_Social_developed_trim = Happiness_mean_Social_developed.drop("Country", 1)
Happiness_Social_developing_trim = Happiness_mean_Social_developing.drop("Country", 1)
Happiness_Social_underdeveloped_trim = Happiness_mean_Social_underdeveloped.drop("Country", 1)



Culture_developed_trim = Culture_developed.drop({"Country","Languages","Region","Religion"}, 1)
Culture_developing_trim = Culture_developing.drop({"Country","Languages","Region","Religion"}, 1)
Culture_underdeveloped_trim = Culture_underdeveloped.drop({"Country","Languages","Region","Religion"}, 1)

Behaviour_developed_trim = Behaviour_developed.drop({"Country"}, 1)
Behaviour_developing_trim = Behaviour_developing.drop({"Country"}, 1)
Behaviour_underdeveloped_trim = Behaviour_underdeveloped.drop({"Country"}, 1)

Economic_developed_trim = Economic_developed.drop({"Country","2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap","2019 GDP per Cap"}, 1)
Economic_developing_trim = Economic_developing.drop({"Country","2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap","2019 GDP per Cap"}, 1)
Economic_underdeveloped_trim = Economic_underdeveloped.drop({"Country","2015 GDP per Cap","2016 GDP per Cap","2017 GDP per Cap","2018 GDP per Cap","2019 GDP per Cap"}, 1)


Social_developed_trim = Social_developed.drop({"Country","2016 Suicide per 100k",
                                           "2016 Suicide 5-14 years","2016 Suicide 15-49 years","2016 Suicide  50-69 years","2016 Suicide 70+ years",
                                           "2015 Suicide per 100k", "2015 Suicide 5-14 years","2015Suicide 15-49 years","2015 Suicide  50-69 years",
                                            "2015 Suicide 70+ years"}, 1)
Social_developing_trim = Social_developing.drop({"Country","2016 Suicide per 100k",
                                           "2016 Suicide 5-14 years","2016 Suicide 15-49 years","2016 Suicide  50-69 years","2016 Suicide 70+ years",
                                           "2015 Suicide per 100k", "2015 Suicide 5-14 years","2015Suicide 15-49 years","2015 Suicide  50-69 years",
                                            "2015 Suicide 70+ years"}, 1)
Social_underdeveloped_trim = Social_underdeveloped.drop({"Country","2016 Suicide per 100k",
                                           "2016 Suicide 5-14 years","2016 Suicide 15-49 years","2016 Suicide  50-69 years","2016 Suicide 70+ years",
                                           "2015 Suicide per 100k", "2015 Suicide 5-14 years","2015Suicide 15-49 years","2015 Suicide  50-69 years",
                                            "2015 Suicide 70+ years"}, 1)
# Out:
#      Prison (per 100k)  Fertility (per woman)  Homicide per 100k  \
# 3                104.0                   1.54               0.50
# 6                170.0                   1.81               0.89
# 7                 98.0                   1.49               0.97
# 10                95.0                   1.70               1.70
# 24               107.0                   1.56               1.76
# 25                81.0                   1.54               0.59
# 37                77.0                   1.50               0.95
# 39                63.0                   1.71               1.01
# 44               124.0                   1.33               0.62
# 47                53.0                   1.65               1.63
# 48               105.0                   1.96               1.20
# 50               140.0                   1.80               1.20
# 64                79.0                   1.85               0.87
# ...

# %%
# Normalise
normed_Happiness_Culture_developed_trim = (Happiness_Culture_developed_trim - Happiness_Culture_developed_trim.min()) / (
    Happiness_Culture_developed_trim.max() - Happiness_Culture_developed_trim.min())

normed_Happiness_Culture_developing_trim = (Happiness_Culture_developing_trim - Happiness_Culture_developing_trim.min()) / (
    Happiness_Culture_developing_trim.max() - Happiness_Culture_developing_trim.min())

normed_Happiness_Culture_underdeveloped_trim = (Happiness_Culture_underdeveloped_trim - Happiness_Culture_underdeveloped_trim.min()) / (
    Happiness_Culture_underdeveloped_trim.max() - Happiness_Culture_underdeveloped_trim.min())



normed_Happiness_Behaviour_developed_trim = (Happiness_Behaviour_developed_trim - Happiness_Behaviour_developed_trim.min()) / (
    Happiness_Behaviour_developed_trim.max() - Happiness_Behaviour_developed_trim.min())

normed_Happiness_Behaviour_developing_trim = (Happiness_Behaviour_developing_trim - Happiness_Behaviour_developing_trim.min()) / (
    Happiness_Behaviour_developing_trim.max() - Happiness_Behaviour_developing_trim.min())

normed_Happiness_Behaviour_underdeveloped_trim = (Happiness_Behaviour_underdeveloped_trim - Happiness_Behaviour_underdeveloped_trim.min()) / (
    Happiness_Behaviour_underdeveloped_trim.max() - Happiness_Behaviour_underdeveloped_trim.min())



normed_Happiness_Economic_developed_trim = (Happiness_Economic_developed_trim - Happiness_Economic_developed_trim.min()) / (
    Happiness_Economic_developed_trim.max() - Happiness_Economic_developed_trim.min())

normed_Happiness_Economic_developing_trim = (Happiness_Economic_developing_trim - Happiness_Economic_developing_trim.min()) / (
    Happiness_Economic_developing_trim.max() - Happiness_Economic_developing_trim.min())

normed_Happiness_Economic_underdeveloped_trim = (Happiness_Economic_underdeveloped_trim - Happiness_Economic_underdeveloped_trim.min()) / (
    Happiness_Economic_underdeveloped_trim.max() - Happiness_Economic_underdeveloped_trim.min())



normed_Happiness_Social_developed_trim = (Happiness_Social_developed_trim - Happiness_Social_developed_trim.min()) / (
    Happiness_Social_developed_trim.max() - Happiness_Social_developed_trim.min())

normed_Happiness_Social_developing_trim = (Happiness_Social_developing_trim - Happiness_Social_developing_trim.min()) / (
    Happiness_Social_developing_trim.max() - Happiness_Social_developing_trim.min())

normed_Happiness_Social_underdeveloped_trim = (Happiness_Social_underdeveloped_trim - Happiness_Social_underdeveloped_trim.min()) / (
    Happiness_Social_underdeveloped_trim.max() - Happiness_Social_underdeveloped_trim.min())

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
Culture_developed_scaled = scaler.fit_transform(Culture_developed_trim) 
Culture_developed_scaled = pd.DataFrame(Culture_developed_scaled, columns=Culture_developed_trim.columns,index=Culture_developed_trim.index)

Culture_developing_scaled = scaler.fit_transform(Culture_developing_trim) 
Culture_developing_scaled = pd.DataFrame(Culture_developing_scaled, columns=Culture_developing_trim.columns,index=Culture_developing_trim.index)

Culture_underdeveloped_scaled = scaler.fit_transform(Culture_underdeveloped_trim) 
Culture_underdeveloped_scaled = pd.DataFrame(Culture_underdeveloped_scaled, columns=Culture_underdeveloped_trim.columns,index=Culture_underdeveloped_trim.index)


Behaviour_developed_scaled = scaler.fit_transform(Behaviour_developed_trim) 
Behaviour_developed_scaled = pd.DataFrame(Behaviour_developed_scaled, columns=Behaviour_developed_trim.columns,index=Behaviour_developed_trim.index)

Behaviour_developing_scaled = scaler.fit_transform(Behaviour_developing_trim) 
Behaviour_developing_scaled = pd.DataFrame(Behaviour_developing_scaled, columns=Behaviour_developing_trim.columns,index=Behaviour_developing_trim.index)

Behaviour_underdeveloped_scaled = scaler.fit_transform(Behaviour_underdeveloped_trim) 
Behaviour_underdeveloped_scaled = pd.DataFrame(Behaviour_underdeveloped_scaled, columns=Behaviour_underdeveloped_trim.columns,index=Behaviour_underdeveloped_trim.index)


Economic_developed_scaled = scaler.fit_transform(Economic_developed_trim) 
Economic_developed_scaled = pd.DataFrame(Economic_developed_scaled, columns=Economic_developed_trim.columns,index=Economic_developed_trim.index)

Economic_developing_scaled = scaler.fit_transform(Economic_developing_trim) 
Economic_developing_scaled = pd.DataFrame(Economic_developing_scaled, columns=Economic_developing_trim.columns,index=Economic_developing_trim.index)

Economic_underdeveloped_scaled = scaler.fit_transform(Economic_underdeveloped_trim) 
Economic_underdeveloped_scaled = pd.DataFrame(Economic_underdeveloped_scaled, columns=Economic_underdeveloped_trim.columns,index=Economic_underdeveloped_trim.index)

Social_developed_scaled = scaler.fit_transform(Social_developed_trim) 
Social_developed_scaled = pd.DataFrame(Social_developed_scaled, columns=Social_developed_trim.columns,index=Social_developed_trim.index)

Social_developing_scaled = scaler.fit_transform(Social_developing_trim) 
Social_developing_scaled = pd.DataFrame(Social_developing_scaled, columns=Social_developing_trim.columns,index=Social_developing_trim.index)

Social_underdeveloped_scaled = scaler.fit_transform(Social_underdeveloped_trim) 
Social_underdeveloped_scaled = pd.DataFrame(Social_underdeveloped_scaled, columns=Social_underdeveloped_trim.columns,index=Social_underdeveloped_trim.index)

# %%
normed_Happiness_Culture_underdeveloped_trim
# Out:
#      Hapiness_Mean
# 0         0.171863
# 9         0.000000
# 11        0.326938
# 12        0.396483
# 22        0.298961
# 23        0.031575
# 28        0.476419
# 29        0.645084
# 30        0.505995
# 31        0.517986
# 33        0.351719
# 46        0.536371
# 49        0.530775
# 52        0.581934
# 53        0.308553
# 54        0.574740
# 60        0.313349
# 74        0.546763
# 79        0.681055
# 81        0.302958
# 84        0.420863
# 90        0.264588
# 93        0.454836
# 95        0.521183
# 98        0.620304
# 99        0.509193
# 101       0.320544
# 103       0.589928
# 104       0.410072
# 105       0.818545
# 109       0.690647
# 112       0.903277
# 123       0.143086
# 126       0.523581
# 128       0.590727
# 130       0.844125
# 132       0.178257
# 137       0.556355
# 138       0.083933
# 139       0.368505
# 140       0.184652
# 142       0.806555
# 143       1.000000
# 147       0.153477
# 148       0.374900
# 156       0.217426
# ...

# %%
Culture_underdeveloped_scaled
# Out:
#      Christian  Folk religion  Buddhist     Hindu  Jewish  Irreligion  \
# 0     0.000922       0.000000  0.000000  0.000372    0.00    0.000000
# 9     0.937494       0.160112  0.000000  0.000000    0.00    0.000000
# 11    0.491751       0.505618  0.000000  0.000000    0.00    0.291262
# 12    0.230454       0.432584  0.000000  0.000000    0.00    0.019417
# 22    0.738703       0.168539  0.000000  0.003717    0.00    1.000000
# 23    0.917000       0.028090  0.000000  0.000000    0.00    0.048544
# 28    0.451788       0.286517  0.000000  0.000000    0.00    0.388350
# 29    0.720258       0.092697  0.000000  0.000000    0.00    0.257282
# 30    0.981555       0.019663  0.000000  0.000620    0.00    0.087379
# 31    0.880111       0.078652  0.000000  0.000000    0.00    0.436893
# 33    0.001947       0.000000  0.000000  0.000000    0.00    0.000000
# 46    0.553233       0.073034  0.000000  0.000000    1.00    0.002913
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Culture_developed_scaled, normed_Happiness_Culture_developed_trim)
rf.score(Culture_developed_scaled, normed_Happiness_Culture_developed_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Culture_developed_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.3735067475970461, 'Buddhist'),
#  (0.13865579766086067, 'Region_Southern Europe'),
#  (0.07244094107152575, 'Region_Northern Europe'),
#  (0.06397818637101228, 'Irreligion'),
#  (0.06122080909251098, 'Christian'),
#  (0.04955391993066461, 'Jewish'),
#  (0.0454955011614023, 'Hindu'),
#  (0.034084793974724026, 'Muslim'),
#  (0.03244137445893295, 'Language_Europe (other)'),
#  (0.025865578256355676, 'Region_Eastern Asia'),
#  (0.024081434686686977, 'Religion_Atheist'),
#  (0.022635665565622708, 'Folk religion'),
#  (0.015066029173391247, 'Religion_Christian'),
#  (0.012182324644476775, 'Other religion'),
#  (0.007692489317432134, 'Language_English'),
#  (0.006557328084232203, 'Language_Spanish'),
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Culture_developing_scaled, normed_Happiness_Culture_developing_trim)
rf.score(Culture_developing_scaled, normed_Happiness_Culture_developing_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Culture_developing_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.2069698332168559, 'Muslim'),
#  (0.16592998503343562, 'Irreligion'),
#  (0.1394326873855393, 'Region_Latin America and Caribbean'),
#  (0.13611347739665314, 'Christian'),
#  (0.06193334727782041, 'Folk religion'),
#  (0.05795570736726303, 'Jewish'),
#  (0.04762154756337157, 'Buddhist'),
#  (0.036092643261527044, 'Other religion'),
#  (0.034708923517972716, 'Hindu'),
#  (0.015809693500072736, 'Region_Central Asia'),
#  (0.015449603585737642, 'Region_Southern Asia'),
#  (0.013095115474442016, 'Language_Spanish'),
#  (0.010874923329498163, 'Language_Russian'),
#  (0.010588188275233222, 'Language_Europe (other)'),
#  (0.006614371800425443, 'Religion_Atheist'),
#  (0.005173747700993666, 'Region_Eastern Europe'),
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Culture_underdeveloped_scaled, normed_Happiness_Culture_underdeveloped_trim)
rf.score(Culture_underdeveloped_scaled, normed_Happiness_Culture_underdeveloped_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Culture_underdeveloped_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.16452023846878164, 'Christian'),
#  (0.13132117003630123, 'Buddhist'),
#  (0.11109061138589946, 'Region_Central Asia'),
#  (0.10429856779449456, 'Irreligion'),
#  (0.09819994461487781, 'Other religion'),
#  (0.08486349287044484, 'Language_Asia (other)'),
#  (0.07737036925376585, 'Muslim'),
#  (0.07656282281093664, 'Folk religion'),
#  (0.026815320109672896, 'Language_French'),
#  (0.02549069904539395, 'Hindu'),
#  (0.02376091400864443, 'Region_Sub-Saharan Africa'),
#  (0.02255024346009483, 'Language_Arabic'),
#  (0.022192318468449372, 'Region_Middle East and Northern Africa'),
#  (0.006848448449528776, 'Religion_Muslim'),
#  (0.006548054379821197, 'Language_Portuguese'),
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Behaviour_developed_scaled, normed_Happiness_Behaviour_developed_trim)
rf.score(Behaviour_developed_scaled, normed_Happiness_Behaviour_developed_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Behaviour_developed_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.5981027197689941, 'Power Distance'),
#  (0.17593996088846273, 'Individualism'),
#  (0.10657209315998431, 'Long Term Orientation'),
#  (0.08015179412171619, 'Masculinity'),
#  (0.03923343206084279, 'Uncertainity Avoidance')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Behaviour_developing_scaled, normed_Happiness_Behaviour_developing_trim)
rf.score(Behaviour_developing_scaled, normed_Happiness_Behaviour_developing_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Behaviour_developing_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.49128743350965615, 'Uncertainity Avoidance'),
#  (0.19576879264901295, 'Individualism'),
#  (0.17884669694363092, 'Masculinity'),
#  (0.10532930612192724, 'Power Distance'),
#  (0.02876777077577274, 'Long Term Orientation')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Behaviour_underdeveloped_scaled, normed_Happiness_Behaviour_underdeveloped_trim)
rf.score(Behaviour_underdeveloped_scaled, normed_Happiness_Behaviour_underdeveloped_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Behaviour_underdeveloped_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.23310883890147188, 'Long Term Orientation'),
#  (0.21695869480853439, 'Uncertainity Avoidance'),
#  (0.19454663251829185, 'Masculinity'),
#  (0.1945066771847609, 'Individualism'),
#  (0.1608791565869411, 'Power Distance')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Economic_developed_scaled, normed_Happiness_Economic_developed_trim)
rf.score(Economic_developed_scaled, normed_Happiness_Economic_developed_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Economic_developed_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.7864415728198689, 'GDP_Mean'),
#  (0.09355037651034753, 'GINI'),
#  (0.0586340444571625, 'Unemployment (%)'),
#  (0.03357878823351256, 'Urbanization (rate)'),
#  (0.027795217979108448, 'Net Migration')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Economic_developing_scaled, normed_Happiness_Economic_developing_trim)
rf.score(Economic_developing_scaled, normed_Happiness_Economic_developing_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Economic_developing_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.6626517975889066, 'GDP_Mean'),
#  (0.16739082464124455, 'Urbanization (rate)'),
#  (0.03905413032858379, 'Unemployment (%)'),
#  (0.03467161533008473, 'Congestion (Per capita)'),
#  (0.03336257294061973, 'GINI'),
#  (0.031229061803310806, 'Air Quality (Value)'),
#  (0.018697158661914563, 'Net Migration'),
#  (0.012942838705335346, 'Hunger (rate)')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Economic_underdeveloped_scaled, normed_Happiness_Economic_underdeveloped_trim)
rf.score(Economic_underdeveloped_scaled, normed_Happiness_Economic_underdeveloped_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Economic_underdeveloped_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.25233644859813087, 'Air Quality (Value)'),
#  (0.16822429906542058, 'GDP_Mean'),
#  (0.14953271028037385, 'Unemployment (%)'),
#  (0.11214953271028039, 'GINI'),
#  (0.10280373831775702, 'Urbanization (rate)'),
#  (0.09345794392523366, 'Net Migration'),
#  (0.08411214953271029, 'Hunger (rate)'),
#  (0.03738317757009346, 'Congestion (Per capita)')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Social_developed_scaled, normed_Happiness_Social_developed_trim)
rf.score(Social_developed_scaled, normed_Happiness_Social_developed_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Social_developed_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.4703418683998692, 'Democracy (value)'),
#  (0.21618090970987697, 'Fertility (per woman)'),
#  (0.07654116648412065, 'Suicide 15-49 years'),
#  (0.045047567259479754, 'Alchool (per cap)'),
#  (0.04194374389363092, 'Gender Ratio %'),
#  (0.031560795107191966, 'Prison (per 100k)'),
#  (0.029806957945851288, 'Suicide 70+ years'),
#  (0.02485443084560155, 'Holiday (Paid Days)'),
#  (0.0234229103384132, 'Homicide per 100k'),
#  (0.022976312787405744, 'Suicide 50-69 years'),
#  (0.017323337228558718, 'Suicide 5-14 years')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Social_underdeveloped_scaled, normed_Happiness_Social_underdeveloped_trim)
rf.score(Social_underdeveloped_scaled, normed_Happiness_Social_underdeveloped_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Social_underdeveloped_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.23204249358485995, 'Holiday (Paid Days)'),
#  (0.19010569315457174, 'Democracy (value)'),
#  (0.09464155986453951, 'Gender Ratio %'),
#  (0.0939088530716677, 'Suicide 50-69 years'),
#  (0.07484112733257325, 'Fertility (per woman)'),
#  (0.06199613966431363, 'Suicide 5-14 years'),
#  (0.05907042522917996, 'Alchool (per cap)'),
#  (0.05820351551325211, 'Prison (per 100k)'),
#  (0.05072009399105365, 'Suicide 70+ years'),
#  (0.0434045211500963, 'Homicide per 100k'),
#  (0.04106557744389227, 'Suicide 15-49 years')]

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200)
rf = rf.fit(Social_developing_scaled, normed_Happiness_Social_developing_trim)
rf.score(Social_developing_scaled, normed_Happiness_Social_developing_trim)

importances = rf.feature_importances_
importances

sorted(zip(rf.feature_importances_, Social_developing_scaled), reverse=True)
# Out:
# C:\Users\Luis Nunes\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# [(0.21047437198672947, 'Prison (per 100k)'),
#  (0.18759111345666804, 'Democracy (value)'),
#  (0.16001546110453493, 'Homicide per 100k'),
#  (0.07449234986551695, 'Holiday (Paid Days)'),
#  (0.07445702299960488, 'Gender Ratio %'),
#  (0.06790742217876533, 'Suicide 5-14 years'),
#  (0.05711227858487853, 'Suicide 70+ years'),
#  (0.05303322613364443, 'Suicide 15-49 years'),
#  (0.04134891486964106, 'Fertility (per woman)'),
#  (0.03795778726990942, 'Alchool (per cap)'),
#  (0.03561005155010685, 'Suicide 50-69 years')]
